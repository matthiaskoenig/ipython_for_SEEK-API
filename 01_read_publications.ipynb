# %% [markdown]
# # SEEK read API

# %% [markdown]
# Example script using the REST API to load the available publications from LiSyM.
#
# We use the official SEEK instance
# https://seek.lisym.org/
# running SEEK v1.8.1 (2019-04-10)
#
# adapted from Wolfgang Müller, HITS

# %%
SEEK_URL = "https://seek.lisym.org/"

# %% [markdown]
# # Read publications from SEEK instance

# %%
import requests
import datetime

def get_json(url):
    print(url)
    r = requests.get(url)
    json = r.json()
    return json['data']

def getAllPublications():
    """ Get JSON for all publications."""
    url = SEEK_URL + 'publications.json'
    return get_json(url)

def getPublication(pid):
    url = SEEK_URL + 'publications/{}.json'.format(pid)
    return get_json(url)

def parsePublication(data):
    # print(data)
    attributes = data['attributes']
    return {
      'id': data['id'],
      'pmid': attributes['pubmed_id'],
      'doi': attributes['doi'],
      'link': attributes['link_to_pub'],  
      'title': attributes['title'],
      'authors': attributes['authors'],
      'abstract': attributes['abstract'],
      'citation': attributes['citation'],
      'journal': attributes['journal'],
      'published_date': attributes['published_date'],
      'projects': data['relationships']['projects']
    }

allPublicationsData = getAllPublications()

publications = []
for item in allPublicationsData:
    print(item)
    id = item["id"]
    fullPublicationData = getPublication(id)
    
    publications.append(parsePublication(fullPublicationData))
print(len(allPublicationsData))
# now "publications" contains a list of hashes with publication information
# Out:
# https://seek.lisym.org/publications.json
# {'id': '1', 'type': 'publications', 'attributes': {'title': 'Specifications of Standards in Systems and Synthetic Biology: Status and Developments in 2016'}, 'links': {'self': '/publications/1'}}
# https://seek.lisym.org/publications/1.json
# {'id': '2', 'type': 'publications', 'attributes': {'title': 'FAIRDOMHub: a repository and collaboration environment for sharing systems biology research'}, 'links': {'self': '/publications/2'}}
# https://seek.lisym.org/publications/2.json
# {'id': '3', 'type': 'publications', 'attributes': {'title': 'The Human Physiome: how standards, software and innovative service infrastructures are providing the building blocks to make it achievable'}, 'links': {'self': '/publications/3'}}
# https://seek.lisym.org/publications/3.json
# {'id': '4', 'type': 'publications', 'attributes': {'title': 'SABIO-RK, von Daten in der Publikation zur Suchlösung für\xa0Spezialisten'}, 'links': {'self': '/publications/4'}}
# https://seek.lisym.org/publications/4.json
# {'id': '5', 'type': 'publications', 'attributes': {'title': 'L1 regularization facilitates detection of cell type-specific parameters in dynamical systems.'}, 'links': {'self': '/publications/5'}}
# https://seek.lisym.org/publications/5.json
# {'id': '6', 'type': 'publications', 'attributes': {'title': 'Identification of Cell Type-Specific Differences in Erythropoietin Receptor Signaling in Primary Erythroid and Lung Cancer Cells.'}, 'links': {'self': '/publications/6'}}
# https://seek.lisym.org/publications/6.json
# {'id': '7', 'type': 'publications', 'attributes': {'title': 'Driving the Model to Its Limit: Profile Likelihood Based Model Reduction.'}, 'links': {'self': '/publications/7'}}
# https://seek.lisym.org/publications/7.json
# {'id': '11', 'type': 'publications', 'attributes': {'title': 'Model-guided identification of a therapeutic strategy to reduce hyperammonemia in liver diseases'}, 'links': {'self': '/publications/11'}}
# https://seek.lisym.org/publications/11.json
# {'id': '12', 'type': 'publications', 'attributes': {'title': 'In vivo imaging of systemic transport and elimination of xenobiotics and endogenous molecules in mice'}, 'links': {'self': '/publications/12'}}
# https://seek.lisym.org/publications/12.json
# {'id': '13', 'type': 'publications', 'attributes': {'title': 'The ascending pathophysiology of cholestatic liver disease'}, 'links': {'self': '/publications/13'}}
# https://seek.lisym.org/publications/13.json
# {'id': '14', 'type': 'publications', 'attributes': {'title': 'Comparison of Gene Expression Patterns Between Mouse Models of Nonalcoholic Fatty Liver Disease and Liver Tissues From Patients.'}, 'links': {'self': '/publications/14'}}
# https://seek.lisym.org/publications/14.json
# {'id': '15', 'type': 'publications', 'attributes': {'title': 'Creation of Three-Dimensional Liver Tissue Models from Experimental Images for Systems Medicine.'}, 'links': {'self': '/publications/15'}}
# https://seek.lisym.org/publications/15.json
# {'id': '17', 'type': 'publications', 'attributes': {'title': 'BMP-9 interferes with liver regeneration and promotes liver fibrosis.'}, 'links': {'self': '/publications/17'}}
# https://seek.lisym.org/publications/17.json
# {'id': '18', 'type': 'publications', 'attributes': {'title': 'Orphan nuclear receptor SHP regulates iron metabolism through inhibition of BMP6-mediated hepcidin expression.'}, 'links': {'self': '/publications/18'}}
# https://seek.lisym.org/publications/18.json
# {'id': '19', 'type': 'publications', 'attributes': {'title': 'Caveolin-1 in the regulation of cell metabolism: a cancer perspective.'}, 'links': {'self': '/publications/19'}}
# https://seek.lisym.org/publications/19.json
# {'id': '20', 'type': 'publications', 'attributes': {'title': 'Global Transcriptional Response of Human Liver Cells to Ethanol Stress of Different Strength Reveals Hormetic Behavior.'}, 'links': {'self': '/publications/20'}}
# https://seek.lisym.org/publications/20.json
# {'id': '21', 'type': 'publications', 'attributes': {'title': 'Evolving Insights on Metabolism, Autophagy, and Epigenetics in Liver Myofibroblasts.'}, 'links': {'self': '/publications/21'}}
# https://seek.lisym.org/publications/21.json
# {'id': '22', 'type': 'publications', 'attributes': {'title': 'Conditional loss of hepatocellular Hedgehog signaling in female mice leads to the persistence of hepatic steroidogenesis, androgenization and infertility'}, 'links': {'self': '/publications/22'}}
# https://seek.lisym.org/publications/22.json
# {'id': '23', 'type': 'publications', 'attributes': {'title': 'Panel of three novel serum markers predicts liver stiffness and fibrosis stages in patients with chronic liver disease.'}, 'links': {'self': '/publications/23'}}
# https://seek.lisym.org/publications/23.json
# {'id': '24', 'type': 'publications', 'attributes': {'title': 'Translational learning from clinical studies predicts drug pharmacokinetics across patient populations'}, 'links': {'self': '/publications/24'}}
# https://seek.lisym.org/publications/24.json
# {'id': '25', 'type': 'publications', 'attributes': {'title': 'DNA Methylation of ADME Genes.'}, 'links': {'self': '/publications/25'}}
# https://seek.lisym.org/publications/25.json
# {'id': '26', 'type': 'publications', 'attributes': {'title': 'The importance of drug transporter characterization to precision medicine.'}, 'links': {'self': '/publications/26'}}
# https://seek.lisym.org/publications/26.json
# {'id': '27', 'type': 'publications', 'attributes': {'title': 'Polymorphic variation in TPMT is the principal determinant of TPMT phenotype: A meta-analysis of three genome-wide association studies.'}, 'links': {'self': '/publications/27'}}
# https://seek.lisym.org/publications/27.json
# {'id': '28', 'type': 'publications', 'attributes': {'title': 'Impact of Membrane Drug Transporters on Resistance to Small-Molecule Tyrosine Kinase Inhibitors.'}, 'links': {'self': '/publications/28'}}
# https://seek.lisym.org/publications/28.json
# {'id': '29', 'type': 'publications', 'attributes': {'title': 'Translational learning from clinical studies predicts drug pharmacokinetics across patient populations.'}, 'links': {'self': '/publications/29'}}
# https://seek.lisym.org/publications/29.json
# {'id': '30', 'type': 'publications', 'attributes': {'title': 'Ligand-dependent and -independent regulation of human hepatic sphingomyelin phosphodiesterase acid-like 3A expression by pregnane X receptor and crosstalk with liver X receptor.'}, 'links': {'self': '/publications/30'}}
# https://seek.lisym.org/publications/30.json
# {'id': '31', 'type': 'publications', 'attributes': {'title': 'Physiologically-based modelling in mice suggests an aggravated loss of clearance capacity after toxic liver damage'}, 'links': {'self': '/publications/31'}}
# https://seek.lisym.org/publications/31.json
# {'id': '32', 'type': 'publications', 'attributes': {'title': 'Physiologically-based modelling in mice suggests an aggravated loss of clearance capacity after toxic liver damage'}, 'links': {'self': '/publications/32'}}
# https://seek.lisym.org/publications/32.json
# {'id': '33', 'type': 'publications', 'attributes': {'title': 'Towards knowledge-driven cross-species extrapolation'}, 'links': {'self': '/publications/33'}}
# https://seek.lisym.org/publications/33.json
# {'id': '34', 'type': 'publications', 'attributes': {'title': 'Large-scale computational models of liver metabolism: How far from the clinics?'}, 'links': {'self': '/publications/34'}}
# https://seek.lisym.org/publications/34.json
# {'id': '35', 'type': 'publications', 'attributes': {'title': 'Computational modelling of Hedgehog signalling in liver regeneration'}, 'links': {'self': '/publications/35'}}
# https://seek.lisym.org/publications/35.json
# {'id': '36', 'type': 'publications', 'attributes': {'title': 'A frequent misinterpretation in current research on liver fibrosis: the vessel in the center of CCl4-induced pseudolobules is a portal vein.'}, 'links': {'self': '/publications/36'}}
# https://seek.lisym.org/publications/36.json
# {'id': '37', 'type': 'publications', 'attributes': {'title': 'Identification of the Consistently Altered Metabolic Targets in Human Hepatocellular Carcinoma'}, 'links': {'self': '/publications/37'}}
# https://seek.lisym.org/publications/37.json
# {'id': '38', 'type': 'publications', 'attributes': {'title': 'Computational Modeling in Liver Surgery'}, 'links': {'self': '/publications/38'}}
# https://seek.lisym.org/publications/38.json
# {'id': '39', 'type': 'publications', 'attributes': {'title': 'Cholestasis-induced adaptive remodeling of interlobular bile ducts.'}, 'links': {'self': '/publications/39'}}
# https://seek.lisym.org/publications/39.json
# {'id': '40', 'type': 'publications', 'attributes': {'title': 'Modeling approaches for hepatic spatial heterogeneity in pharmacokinetic simulations'}, 'links': {'self': '/publications/40'}}
# https://seek.lisym.org/publications/40.json
# {'id': '41', 'type': 'publications', 'attributes': {'title': 'Hepatic Smad7-overexpression causes severe iron overload in the mouse.'}, 'links': {'self': '/publications/41'}}
# https://seek.lisym.org/publications/41.json
# {'id': '43', 'type': 'publications', 'attributes': {'title': 'Pharmacokinetics and pharmacodynamics of thiopurines in an in vitro model of human hepatocytes: Insights from an innovative mass spectrometry assay.'}, 'links': {'self': '/publications/43'}}
# https://seek.lisym.org/publications/43.json
# {'id': '44', 'type': 'publications', 'attributes': {'title': 'A Predictive 3D Multi-Scale Model of Biliary Fluid Dynamics in the Liver Lobule'}, 'links': {'self': '/publications/44'}}
# https://seek.lisym.org/publications/44.json
# {'id': '45', 'type': 'publications', 'attributes': {'title': 'pSSAlib: The partial-propensity stochastic chemical network simulator'}, 'links': {'self': '/publications/45'}}
# https://seek.lisym.org/publications/45.json
# {'id': '48', 'type': 'publications', 'attributes': {'title': 'Hedgehog signaling is a potent regulator of liver lipid metabolism and reveals a GLI-code associated with steatosis.'}, 'links': {'self': '/publications/48'}}
# https://seek.lisym.org/publications/48.json
# {'id': '49', 'type': 'publications', 'attributes': {'title': 'Monitoring Membrane Lipidome Turnover by Metabolic (15)N Labeling and Shotgun Ultra-High-Resolution Orbitrap Fourier Transform Mass Spectrometry.'}, 'links': {'self': '/publications/49'}}
# https://seek.lisym.org/publications/49.json
# {'id': '50', 'type': 'publications', 'attributes': {'title': 'Intensity-Independent Noise Filtering in FT MS and FT MS/MS Spectra for Shotgun Lipidomics.'}, 'links': {'self': '/publications/50'}}
# https://seek.lisym.org/publications/50.json
# {'id': '51', 'type': 'publications', 'attributes': {'title': 'Lipidomics of Human Blood Plasma by High-Resolution Shotgun Mass Spectrometry.'}, 'links': {'self': '/publications/51'}}
# https://seek.lisym.org/publications/51.json
# {'id': '52', 'type': 'publications', 'attributes': {'title': 'Gender, Contraceptives and Individual Metabolic Predisposition Shape a Healthy Plasma Lipidome.'}, 'links': {'self': '/publications/52'}}
# https://seek.lisym.org/publications/52.json
# {'id': '53', 'type': 'publications', 'attributes': {'title': 'BMP-9 interferes with liver regeneration and promotes liver fibrosis.'}, 'links': {'self': '/publications/53'}}
# https://seek.lisym.org/publications/53.json
# {'id': '54', 'type': 'publications', 'attributes': {'title': 'Model Based Targeting of IL-6-Induced Inflammatory Responses in Cultured Primary Hepatocytes to Improve Application of the JAK Inhibitor Ruxolitinib.'}, 'links': {'self': '/publications/54'}}
# https://seek.lisym.org/publications/54.json
# {'id': '56', 'type': 'publications', 'attributes': {'title': 'Bio-degradable highly fluorescent conjugated polymer nanoparticles for bio-medical imaging applications'}, 'links': {'self': '/publications/56'}}
# https://seek.lisym.org/publications/56.json
# {'id': '57', 'type': 'publications', 'attributes': {'title': 'A brief history of COMBINE'}, 'links': {'self': '/publications/57'}}
# https://seek.lisym.org/publications/57.json
# {'id': '58', 'type': 'publications', 'attributes': {'title': 'A Predictive 3D Multi-Scale Model of Biliary Fluid Dynamics in the Liver Lobule.'}, 'links': {'self': '/publications/58'}}
# https://seek.lisym.org/publications/58.json
# {'id': '59', 'type': 'publications', 'attributes': {'title': 'Ethanol sensitizes hepatocytes for TGF-β-triggered apoptosis'}, 'links': {'self': '/publications/59'}}
# https://seek.lisym.org/publications/59.json
# {'id': '60', 'type': 'publications', 'attributes': {'title': 'The level of caveolin-1 expression determines response to TGF-β as a tumour suppressor in hepatocellular carcinoma cells'}, 'links': {'self': '/publications/60'}}
# https://seek.lisym.org/publications/60.json
# {'id': '61', 'type': 'publications', 'attributes': {'title': 'Orphan nuclear receptor ERRγ is a key regulator of human fibrinogen gene expression'}, 'links': {'self': '/publications/61'}}
# https://seek.lisym.org/publications/61.json
# {'id': '62', 'type': 'publications', 'attributes': {'title': 'Robust detection and segmentation of cell nuclei in biomedical images based on a computational topology framework'}, 'links': {'self': '/publications/62'}}
# https://seek.lisym.org/publications/62.json
# {'id': '63', 'type': 'publications', 'attributes': {'title': 'Hepatocyte-specific Smad7 deletion accelerates DEN-induced HCC via activation of STAT3 signaling in mice'}, 'links': {'self': '/publications/63'}}
# https://seek.lisym.org/publications/63.json
# {'id': '64', 'type': 'publications', 'attributes': {'title': 'Delta-Like Ligand 4 Modulates Liver Damage by Down-Regulating Chemokine Expression'}, 'links': {'self': '/publications/64'}}
# https://seek.lisym.org/publications/64.json
# {'id': '65', 'type': 'publications', 'attributes': {'title': 'Transforming Growth Factor β1 (TGF-β1) Activates Hepcidin mRNA Expression in Hepatocytes'}, 'links': {'self': '/publications/65'}}
# https://seek.lisym.org/publications/65.json
# {'id': '66', 'type': 'publications', 'attributes': {'title': 'TGF-&#x3B2;1 and TGF-&#x3B2;2 abundance in liver diseases of mice and men'}, 'links': {'self': '/publications/66'}}
# https://seek.lisym.org/publications/66.json
# {'id': '67', 'type': 'publications', 'attributes': {'title': 'Quantification of substrate and cellular strains in stretchable 3D cell cultures: an experimental and computational framework'}, 'links': {'self': '/publications/67'}}
# https://seek.lisym.org/publications/67.json
# {'id': '68', 'type': 'publications', 'attributes': {'title': 'Global Transcriptional Response of Human Liver Cells to Ethanol Stress of Different Strength Reveals Hormetic Behavior'}, 'links': {'self': '/publications/68'}}
# https://seek.lisym.org/publications/68.json
# {'id': '69', 'type': 'publications', 'attributes': {'title': 'Quantitative and integrative analysis of paracrine hepatocyte activation by nonparenchymal cells upon lipopolysaccharide induction'}, 'links': {'self': '/publications/69'}}
# https://seek.lisym.org/publications/69.json
# {'id': '70', 'type': 'publications', 'attributes': {'title': 'Tomoelastography of the abdomen: Tissue mechanical properties of the liver, spleen, kidney, and pancreas from single MR elastography scans at different hydration states.'}, 'links': {'self': '/publications/70'}}
# https://seek.lisym.org/publications/70.json
# {'id': '71', 'type': 'publications', 'attributes': {'title': 'Tomoelastography of the prostate using multifrequency MR elastography and externally placed pressurized-air drivers.'}, 'links': {'self': '/publications/71'}}
# https://seek.lisym.org/publications/71.json
# {'id': '72', 'type': 'publications', 'attributes': {'title': 'Tomoelastography of the native kidney: Regional variation and physiological effects on in vivo renal stiffness.'}, 'links': {'self': '/publications/72'}}
# https://seek.lisym.org/publications/72.json
# {'id': '73', 'type': 'publications', 'attributes': {'title': 'Physiologic Reduction of Hepatic Venous Blood Flow by the Valsalva Maneuver Decreases Liver Stiffness.'}, 'links': {'self': '/publications/73'}}
# https://seek.lisym.org/publications/73.json
# {'id': '74', 'type': 'publications', 'attributes': {'title': 'A compact 0.5 T MR elastography device and its application for studying viscoelasticity changes in biological tissues during progressive formalin fixation.'}, 'links': {'self': '/publications/74'}}
# https://seek.lisym.org/publications/74.json
# {'id': '75', 'type': 'publications', 'attributes': {'title': 'The formation of estrogen-like tamoxifen metabolites and their influence on enzyme activity and gene expression of ADME genes.'}, 'links': {'self': '/publications/75'}}
# https://seek.lisym.org/publications/75.json
# {'id': '77', 'type': 'publications', 'attributes': {'title': 'Computational Modeling of Lipid Metabolism in Yeast.'}, 'links': {'self': '/publications/77'}}
# https://seek.lisym.org/publications/77.json
# {'id': '78', 'type': 'publications', 'attributes': {'title': 'Computational Lipidomics and Lipid Bioinformatics: Filling In the Blanks.'}, 'links': {'self': '/publications/78'}}
# https://seek.lisym.org/publications/78.json
# {'id': '80', 'type': 'publications', 'attributes': {'title': 'Effects of Gene Variants Controlling\r\nVitamin D Metabolism and Serum\r\nLevels on Hepatic Steatosis'}, 'links': {'self': '/publications/80'}}
# https://seek.lisym.org/publications/80.json
# {'id': '82', 'type': 'publications', 'attributes': {'title': 'Adverse outcome pathways: opportunities, limitations and open questions.'}, 'links': {'self': '/publications/82'}}
# https://seek.lisym.org/publications/82.json
# {'id': '85', 'type': 'publications', 'attributes': {'title': 'Model prediction and validation of an order mechanism controlling the spatio-temporal phenotype of early hepatocellular carcinoma'}, 'links': {'self': '/publications/85'}}
# https://seek.lisym.org/publications/85.json
# {'id': '86', 'type': 'publications', 'attributes': {'title': 'Quantitative analysis of hepatic macro- and microvascular alterations during cirrhogenesis in the rat.'}, 'links': {'self': '/publications/86'}}
# https://seek.lisym.org/publications/86.json
# {'id': '87', 'type': 'publications', 'attributes': {'title': 'Serum metabolic signatures in patients with overt hepatic encephalopathy.'}, 'links': {'self': '/publications/87'}}
# https://seek.lisym.org/publications/87.json
# {'id': '88', 'type': 'publications', 'attributes': {'title': "4-O'-methylhonokiol protects from alcohol/carbon tetrachloride-induced liver injury in mice."}, 'links': {'self': '/publications/88'}}
# https://seek.lisym.org/publications/88.json
# {'id': '89', 'type': 'publications', 'attributes': {'title': 'Pathophysiology and Management of Alcoholic Liver Disease: Update 2016.'}, 'links': {'self': '/publications/89'}}
# https://seek.lisym.org/publications/89.json
# {'id': '90', 'type': 'publications', 'attributes': {'title': 'Epigenome-wide association study of body mass index, and the adverse outcomes of adiposity.'}, 'links': {'self': '/publications/90'}}
# https://seek.lisym.org/publications/90.json
# {'id': '91', 'type': 'publications', 'attributes': {'title': 'NAFLD is associated with methylation shifts with relevance for the expression of genes involved in lipoprotein particle composition.'}, 'links': {'self': '/publications/91'}}
# https://seek.lisym.org/publications/91.json
# {'id': '92', 'type': 'publications', 'attributes': {'title': 'The genetics of alcohol dependence and alcohol-related liver disease.'}, 'links': {'self': '/publications/92'}}
# https://seek.lisym.org/publications/92.json
# {'id': '93', 'type': 'publications', 'attributes': {'title': 'A targeted analysis reveals relevant shifts in the methylation and transcription of genes responsible for bile acid homeostasis and drug metabolism in non-alcoholic fatty liver disease.'}, 'links': {'self': '/publications/93'}}
# https://seek.lisym.org/publications/93.json
# {'id': '94', 'type': 'publications', 'attributes': {'title': 'Longitudinal micro-computed tomography monitoring of progressive liver regeneration in a mouse model of partial hepatectomy.'}, 'links': {'self': '/publications/94'}}
# https://seek.lisym.org/publications/94.json
# {'id': '95', 'type': 'publications', 'attributes': {'title': 'Toward Community Standards and Software for Whole-Cell Modeling.'}, 'links': {'self': '/publications/95'}}
# https://seek.lisym.org/publications/95.json
# {'id': '96', 'type': 'publications', 'attributes': {'title': 'Functional properties of hepatocytes in vitro are correlated with cell polarity maintenance.'}, 'links': {'self': '/publications/96'}}
# https://seek.lisym.org/publications/96.json
# {'id': '97', 'type': 'publications', 'attributes': {'title': 'Galunisertib modifies the liver fibrotic composition in the Abcb4Ko mouse model'}, 'links': {'self': '/publications/97'}}
# https://seek.lisym.org/publications/97.json
# {'id': '98', 'type': 'publications', 'attributes': {'title': 'Confounding influence of tamoxifen in mouse models of Cre recombinase-induced gene activity or modulation'}, 'links': {'self': '/publications/98'}}
# https://seek.lisym.org/publications/98.json
# {'id': '99', 'type': 'publications', 'attributes': {'title': 'Shotgun Lipidomics Combined with Laser Capture Microdissection: A Tool To Analyze Histological Zones in Cryosections of Tissues.'}, 'links': {'self': '/publications/99'}}
# https://seek.lisym.org/publications/99.json
# {'id': '100', 'type': 'publications', 'attributes': {'title': 'Spatio-temporal visualization of the distribution of acetaminophen as well as its metabolites and adducts in mouse livers by MALDI MSI'}, 'links': {'self': '/publications/100'}}
# https://seek.lisym.org/publications/100.json
# {'id': '101', 'type': 'publications', 'attributes': {'title': 'Bile micro-infarcts in cholestasis are initiated by rupture of the apical hepatocyte membrane and cause shunting of bile to sinusoidal blood'}, 'links': {'self': '/publications/101'}}
# https://seek.lisym.org/publications/101.json
# {'id': '104', 'type': 'publications', 'attributes': {'title': 'Focused scores enable reliable discrimination of small differences in steatosis.'}, 'links': {'self': '/publications/104'}}
# https://seek.lisym.org/publications/104.json
# {'id': '105', 'type': 'publications', 'attributes': {'title': 'Correction to: Meeting report from the fourth meeting of the Computational Modeling in Biology Network (COMBINE).'}, 'links': {'self': '/publications/105'}}
# https://seek.lisym.org/publications/105.json
# {'id': '106', 'type': 'publications', 'attributes': {'title': 'Effect of alcohol on the interleukin 6-mediated inflammatory response in a new mouse model of acute-on-chronic liver injury.'}, 'links': {'self': '/publications/106'}}
# https://seek.lisym.org/publications/106.json
# {'id': '108', 'type': 'publications', 'attributes': {'title': 'Liver-specific Repin1 deficiency impairs transient hepatic steatosis in liver regeneration.'}, 'links': {'self': '/publications/108'}}
# https://seek.lisym.org/publications/108.json
# {'id': '109', 'type': 'publications', 'attributes': {'title': 'ABCB4 Gene Aberrations in Human Liver Disease: An Evolving Spectrum'}, 'links': {'self': '/publications/109'}}
# https://seek.lisym.org/publications/109.json
# {'id': '116', 'type': 'publications', 'attributes': {'title': 'Effects of Gene Variants Controlling Vitamin D Metabolism and Serum Levels on Hepatic Steatosis.'}, 'links': {'self': '/publications/116'}}
# https://seek.lisym.org/publications/116.json
# {'id': '117', 'type': 'publications', 'attributes': {'title': 'Analytical challenges in human plasma lipidomics: A winding path towards the truth'}, 'links': {'self': '/publications/117'}}
# https://seek.lisym.org/publications/117.json
# {'id': '118', 'type': 'publications', 'attributes': {'title': 'Epigenomic map of human liver reveals principles of zonated morphogenic and metabolic control'}, 'links': {'self': '/publications/118'}}
# https://seek.lisym.org/publications/118.json
# {'id': '119', 'type': 'publications', 'attributes': {'title': 'The Diurnal Timing of Starvation Differently Impacts Murine Hepatic Gene Expression and Lipid Metabolism – A Systems Biology Analysis Using Self-Organizing Maps'}, 'links': {'self': '/publications/119'}}
# https://seek.lisym.org/publications/119.json
# {'id': '120', 'type': 'publications', 'attributes': {'title': 'Clinical and Functional Relevance of the Monocarboxylate Transporter Family in Disease Pathophysiology and Drug Therapy.'}, 'links': {'self': '/publications/120'}}
# https://seek.lisym.org/publications/120.json
# {'id': '121', 'type': 'publications', 'attributes': {'title': 'The fruit fly Drosophila melanogaster as an innovative preclinical ADME model for solute carrier membrane transporters, with consequences for pharmacology and drug therapy.'}, 'links': {'self': '/publications/121'}}
# https://seek.lisym.org/publications/121.json
# {'id': '124', 'type': 'publications', 'attributes': {'title': 'Liquid-crystal organization of liver tissue'}, 'links': {'self': '/publications/124'}}
# https://seek.lisym.org/publications/124.json
# {'id': '125', 'type': 'publications', 'attributes': {'title': 'Tomoelastography for the Evaluation of Pediatric Nonalcoholic Fatty Liver Disease'}, 'links': {'self': '/publications/125'}}
# https://seek.lisym.org/publications/125.json
# {'id': '126', 'type': 'publications', 'attributes': {'title': 'US Time-Harmonic Elastography: Detection of Liver Fibrosis in                     Adolescents with Extreme Obesity with Nonalcoholic Fatty Liver                     Disease'}, 'links': {'self': '/publications/126'}}
# https://seek.lisym.org/publications/126.json
# {'id': '127', 'type': 'publications', 'attributes': {'title': 'Genetic determinants of steatosis and fibrosis progression in pediatric non-alcoholic fatty liver disease.'}, 'links': {'self': '/publications/127'}}
# https://seek.lisym.org/publications/127.json
# {'id': '128', 'type': 'publications', 'attributes': {'title': 'Specifications of Standards in Systems and Synthetic Biology: Status and Developments in 2017.'}, 'links': {'self': '/publications/128'}}
# https://seek.lisym.org/publications/128.json
# {'id': '129', 'type': 'publications', 'attributes': {'title': 'Harmonizing semantic annotations for computational models in biology.'}, 'links': {'self': '/publications/129'}}
# https://seek.lisym.org/publications/129.json
# {'id': '130', 'type': 'publications', 'attributes': {'title': 'Data Formats for Systems Biology and Quantitative Modeling'}, 'links': {'self': '/publications/130'}}
# https://seek.lisym.org/publications/130.json
# {'id': '131', 'type': 'publications', 'attributes': {'title': 'A multiscale modelling approach to assess the impact of metabolic zonation and microperfusion on the hepatic carbohydrate metabolism.'}, 'links': {'self': '/publications/131'}}
# https://seek.lisym.org/publications/131.json
# {'id': '132', 'type': 'publications', 'attributes': {'title': 'HEPATOKIN1 is a biochemistry-based model of liver metabolism for applications in medicine and pharmacology.'}, 'links': {'self': '/publications/132'}}
# https://seek.lisym.org/publications/132.json
# {'id': '133', 'type': 'publications', 'attributes': {'title': 'Possible neurotoxicity of the anesthetic propofol: evidence for the inhibition of complex II of the respiratory chain in area CA3 of rat hippocampal slices.'}, 'links': {'self': '/publications/133'}}
# https://seek.lisym.org/publications/133.json
# {'id': '134', 'type': 'publications', 'attributes': {'title': 'Epigenomic map of human liver reveals principles of zonated morphogenic and metabolic control'}, 'links': {'self': '/publications/134'}}
# https://seek.lisym.org/publications/134.json
# {'id': '135', 'type': 'publications', 'attributes': {'title': 'Genetic variants in PNPLA3 and TM6SF2 predispose to the development of hepatocellular carcinoma in individuals with alcohol-related cirrhosis'}, 'links': {'self': '/publications/135'}}
# https://seek.lisym.org/publications/135.json
# {'id': '136', 'type': 'publications', 'attributes': {'title': 'Model-based identification of TNFalpha-induced IKKbeta-mediated and IkappaBalpha-mediated regulation of NFkappaB signal transduction as a tool to quantify the impact of drug-induced liver injury compounds.'}, 'links': {'self': '/publications/136'}}
# https://seek.lisym.org/publications/136.json
# {'id': '137', 'type': 'publications', 'attributes': {'title': 'Resolving the Combinatorial Complexity of Smad Protein Complex Formation and Its Link to Gene Expression.'}, 'links': {'self': '/publications/137'}}
# https://seek.lisym.org/publications/137.json
# {'id': '138', 'type': 'publications', 'attributes': {'title': 'Histologic improvement of NAFLD in patients with obesity after bariatric surgery based on standardized NAS (NAFLD activity score).'}, 'links': {'self': '/publications/138'}}
# https://seek.lisym.org/publications/138.json
# {'id': '139', 'type': 'publications', 'attributes': {'title': 'Whither systems medicine?'}, 'links': {'self': '/publications/139'}}
# https://seek.lisym.org/publications/139.json
# {'id': '140', 'type': 'publications', 'attributes': {'title': '3D visualization of the biliary tree by X-ray phase-contrast computed tomography'}, 'links': {'self': '/publications/140'}}
# https://seek.lisym.org/publications/140.json
# {'id': '141', 'type': 'publications', 'attributes': {'title': 'Single cell polarity in liquid phase facilitates tumour metastasis.'}, 'links': {'self': '/publications/141'}}
# https://seek.lisym.org/publications/141.json
# {'id': '143', 'type': 'publications', 'attributes': {'title': 'The ascending pathophysiology of cholestatic liver disease.'}, 'links': {'self': '/publications/143'}}
# https://seek.lisym.org/publications/143.json
# {'id': '144', 'type': 'publications', 'attributes': {'title': 'Systemic regulation of bilirubin homeostasis: Potential benefits of hyperbilirubinemia'}, 'links': {'self': '/publications/144'}}
# https://seek.lisym.org/publications/144.json
# {'id': '145', 'type': 'publications', 'attributes': {'title': 'Liver cancer cell lines distinctly mimic the metabolic gene expression pattern of the corresponding human tumours.'}, 'links': {'self': '/publications/145'}}
# https://seek.lisym.org/publications/145.json
# {'id': '146', 'type': 'publications', 'attributes': {'title': 'Simulation Experiment Description Markup Language (SED-ML) Level 1 Version 3 (L1V3).'}, 'links': {'self': '/publications/146'}}
# https://seek.lisym.org/publications/146.json
# {'id': '147', 'type': 'publications', 'attributes': {'title': 'Tellurium: An extensible python-based modeling environment for systems and synthetic biology.'}, 'links': {'self': '/publications/147'}}
# https://seek.lisym.org/publications/147.json
# {'id': '148', 'type': 'publications', 'attributes': {'title': 'Tellurium notebooks-An environment for reproducible dynamical modeling in systems biology.'}, 'links': {'self': '/publications/148'}}
# https://seek.lisym.org/publications/148.json
# {'id': '149', 'type': 'publications', 'attributes': {'title': 'Effect of alcohol on the interleukin 6-mediated inflammatory response in a new mouse model of acute-on-chronic liver injury'}, 'links': {'self': '/publications/149'}}
# https://seek.lisym.org/publications/149.json
# {'id': '150', 'type': 'publications', 'attributes': {'title': 'MicroRNA-942 mediates hepatic stellate cell activation by regulating BAMBI expression in human liver fibrosis.'}, 'links': {'self': '/publications/150'}}
# https://seek.lisym.org/publications/150.json
# {'id': '151', 'type': 'publications', 'attributes': {'title': 'Inverse agonist of ERRgamma reduces cannabinoid receptor type 1-mediated induction of fibrinogen synthesis in mice with a high-fat diet-intoxicated liver.'}, 'links': {'self': '/publications/151'}}
# https://seek.lisym.org/publications/151.json
# {'id': '152', 'type': 'publications', 'attributes': {'title': 'Ethanol sensitizes hepatocytes for TGF-beta-triggered apoptosis.'}, 'links': {'self': '/publications/152'}}
# https://seek.lisym.org/publications/152.json
# {'id': '153', 'type': 'publications', 'attributes': {'title': 'Hepatic\n              Smad7\n              overexpression causes severe iron overload in mice'}, 'links': {'self': '/publications/153'}}
# https://seek.lisym.org/publications/153.json
# {'id': '154', 'type': 'publications', 'attributes': {'title': 'Evolutionary Distance Predicts Recurrence After Liver Transplantation in Multifocal Hepatocellular Carcinoma.'}, 'links': {'self': '/publications/154'}}
# https://seek.lisym.org/publications/154.json
# {'id': '155', 'type': 'publications', 'attributes': {'title': 'Second exposure to acetaminophen overdose is associated with liver fibrosis in mice'}, 'links': {'self': '/publications/155'}}
# https://seek.lisym.org/publications/155.json
# {'id': '156', 'type': 'publications', 'attributes': {'title': 'Non-invasive structure-function assessment of the liver by 2D time-harmonic elastography and the dynamic Liver MAximum capacity (LiMAx) test.'}, 'links': {'self': '/publications/156'}}
# https://seek.lisym.org/publications/156.json
# {'id': '157', 'type': 'publications', 'attributes': {'title': 'Hepatic CYP1A2 activity in liver tumors and the implications for preoperative volume-function analysis.'}, 'links': {'self': '/publications/157'}}
# https://seek.lisym.org/publications/157.json
# {'id': '158', 'type': 'publications', 'attributes': {'title': 'Wet-tip versus dry-tip regimes of osmotically driven fluid flow'}, 'links': {'self': '/publications/158'}}
# https://seek.lisym.org/publications/158.json
# {'id': '159', 'type': 'publications', 'attributes': {'title': 'Common NOD2 Risk Variants as Major Susceptibility Factors for Bacterial Infections in Compensated Cirrhosis.'}, 'links': {'self': '/publications/159'}}
# https://seek.lisym.org/publications/159.json
# {'id': '160', 'type': 'publications', 'attributes': {'title': 'Glial cell line-derived neurotrophic factor (GDNF) mediates hepatic stellate cell activation via ALK5/Smad signalling.'}, 'links': {'self': '/publications/160'}}
# https://seek.lisym.org/publications/160.json
# {'id': '161', 'type': 'publications', 'attributes': {'title': 'Aged Abcb4-/- mice upon acute sublethal chemical insult recapitulate features of acute-on-chronic liver failure in patients'}, 'links': {'self': '/publications/161'}}
# https://seek.lisym.org/publications/161.json
# {'id': '162', 'type': 'publications', 'attributes': {'title': 'ECM1 is a gatekeeper that restrains TGF-β activation to maintain liver homeostasis and prevent fibrogenesis'}, 'links': {'self': '/publications/162'}}
# https://seek.lisym.org/publications/162.json
# {'id': '163', 'type': 'publications', 'attributes': {'title': 'Simultaneous isolation of parenchymal and non-parenchymal cells from healthy and diseased mice liver'}, 'links': {'self': '/publications/163'}}
# https://seek.lisym.org/publications/163.json
# {'id': '164', 'type': 'publications', 'attributes': {'title': 'Jagged-1 upregulation in stressed hepatocytes is crucial for liver regeneration'}, 'links': {'self': '/publications/164'}}
# https://seek.lisym.org/publications/164.json
# {'id': '165', 'type': 'publications', 'attributes': {'title': 'Cellular and nuclear hepatocyte ploidy represent a repository in regenerating livers'}, 'links': {'self': '/publications/165'}}
# https://seek.lisym.org/publications/165.json
# {'id': '166', 'type': 'publications', 'attributes': {'title': 'Liver cell type specific discrimination of TGF-beta signaling and outcome in vitro and in vivo'}, 'links': {'self': '/publications/166'}}
# https://seek.lisym.org/publications/166.json
# {'id': '167', 'type': 'publications', 'attributes': {'title': 'CYP2E1 recovery is associated with a pericentral fibrosis pattern after repeated CCl4 insults'}, 'links': {'self': '/publications/167'}}
# https://seek.lisym.org/publications/167.json
# {'id': '168', 'type': 'publications', 'attributes': {'title': 'Transcription factor TRIM33 controls liver progenitor cell towards hepatocyte differentiation through synergizing with phosphorylated Smad2/3 in liver cirrhosis'}, 'links': {'self': '/publications/168'}}
# https://seek.lisym.org/publications/168.json
# {'id': '169', 'type': 'publications', 'attributes': {'title': 'Maintenance of functional hepatocellular polarity determines recovery in acute-on-chronic liver failure'}, 'links': {'self': '/publications/169'}}
# https://seek.lisym.org/publications/169.json
# {'id': '170', 'type': 'publications', 'attributes': {'title': 'Liquid-crystal organization of liver tissue.'}, 'links': {'self': '/publications/170'}}
# https://seek.lisym.org/publications/170.json
# {'id': '171', 'type': 'publications', 'attributes': {'title': 'Correlative SMLM and electron tomography reveals endosome nanoscale domains.'}, 'links': {'self': '/publications/171'}}
# https://seek.lisym.org/publications/171.json
# {'id': '173', 'type': 'publications', 'attributes': {'title': 'Electrosurgical liver resection has a superior regeneration outcome as compared to en-bloc ligation in a novel model of partial hepatectomy in mice'}, 'links': {'self': '/publications/173'}}
# https://seek.lisym.org/publications/173.json
# {'id': '174', 'type': 'publications', 'attributes': {'title': 'Tick-tock hedgehog-mutual crosstalk with liver circadian clock promotes liver steatosis.'}, 'links': {'self': '/publications/174'}}
# https://seek.lisym.org/publications/174.json
# {'id': '175', 'type': 'publications', 'attributes': {'title': 'beta-Catenin and Yes-Associated Protein 1 Cooperate in Hepatoblastoma Pathogenesis.'}, 'links': {'self': '/publications/175'}}
# https://seek.lisym.org/publications/175.json
# {'id': '176', 'type': 'publications', 'attributes': {'title': 'Local Riemannian geometry of model manifolds and its implications for practical parameter identifiability'}, 'links': {'self': '/publications/176'}}
# https://seek.lisym.org/publications/176.json
# {'id': '177', 'type': 'publications', 'attributes': {'title': 'Mapping connections in signaling networks with ambiguous modularity.'}, 'links': {'self': '/publications/177'}}
# https://seek.lisym.org/publications/177.json
# {'id': '178', 'type': 'publications', 'attributes': {'title': 'Specifications of Standards in Systems and Synthetic Biology: Status and Developments in 2019'}, 'links': {'self': '/publications/178'}}
# https://seek.lisym.org/publications/178.json
# {'id': '179', 'type': 'publications', 'attributes': {'title': 'The Systems Biology Markup Language (SBML): Language Specification for Level 3 Version 2 Core Release 2.'}, 'links': {'self': '/publications/179'}}
# https://seek.lisym.org/publications/179.json
# {'id': '180', 'type': 'publications', 'attributes': {'title': 'Characterization of Lipid and Lipid Droplet Metabolism in Human HCC.'}, 'links': {'self': '/publications/180'}}
# https://seek.lisym.org/publications/180.json
# {'id': '181', 'type': 'publications', 'attributes': {'title': 'ECM1 Prevents Activation of Transforming Growth Factor beta, Hepatic Stellate Cells, and Fibrogenesis in Mice.'}, 'links': {'self': '/publications/181'}}
# https://seek.lisym.org/publications/181.json
# {'id': '182', 'type': 'publications', 'attributes': {'title': 'Cooperative and distinct functions of MK2 and MK3 in the regulation of the macrophage transcriptional response to lipopolysaccharide.'}, 'links': {'self': '/publications/182'}}
# https://seek.lisym.org/publications/182.json
# {'id': '185', 'type': 'publications', 'attributes': {'title': 'Benchmark and integration of resources for the estimation of human transcription factor activities'}, 'links': {'self': '/publications/185'}}
# https://seek.lisym.org/publications/185.json
# {'id': '186', 'type': 'publications', 'attributes': {'title': 'Full-Field-of-View Time-Harmonic Elastography of the Native Kidney.'}, 'links': {'self': '/publications/186'}}
# https://seek.lisym.org/publications/186.json
# {'id': '187', 'type': 'publications', 'attributes': {'title': 'The importance of membrane microdomains for bile salt-dependent biliary lipid secretion.'}, 'links': {'self': '/publications/187'}}
# https://seek.lisym.org/publications/187.json
# {'id': '188', 'type': 'publications', 'attributes': {'title': 'Could inherited predisposition drive non-obese fatty liver disease? Results from German tertiary referral centers.'}, 'links': {'self': '/publications/188'}}
# https://seek.lisym.org/publications/188.json
# {'id': '191', 'type': 'publications', 'attributes': {'title': 'A multilevel framework to reconstruct anatomical 3D models of the hepatic vasculature in rat livers'}, 'links': {'self': '/publications/191'}}
# https://seek.lisym.org/publications/191.json
# {'id': '192', 'type': 'publications', 'attributes': {'title': 'Three-dimensional spatially resolved geometrical and functional models of human liver tissue reveal new aspects of NAFLD progression.'}, 'links': {'self': '/publications/192'}}
# https://seek.lisym.org/publications/192.json
# {'id': '195', 'type': 'publications', 'attributes': {'title': 'Influence of Liver Fibrosis on Lobular Zonation'}, 'links': {'self': '/publications/195'}}
# https://seek.lisym.org/publications/195.json
# {'id': '196', 'type': 'publications', 'attributes': {'title': 'Data Management in Computational Systems Biology: Exploring Standards, Tools, Databases, and Packaging Best Practices.'}, 'links': {'self': '/publications/196'}}
# https://seek.lisym.org/publications/196.json
# {'id': '197', 'type': 'publications', 'attributes': {'title': 'Quantitative MRI for Assessment of Treatment Outcomes in a Rabbit VX2 Hepatic Tumor Model.'}, 'links': {'self': '/publications/197'}}
# https://seek.lisym.org/publications/197.json
# {'id': '198', 'type': 'publications', 'attributes': {'title': 'Tomoelastography for non-invasive detection and treatment monitoring in acute appendicitis.'}, 'links': {'self': '/publications/198'}}
# https://seek.lisym.org/publications/198.json
# {'id': '199', 'type': 'publications', 'attributes': {'title': 'Tomoelastography Distinguishes Noninvasively between Benign and Malignant Liver Lesions.'}, 'links': {'self': '/publications/199'}}
# https://seek.lisym.org/publications/199.json
# {'id': '200', 'type': 'publications', 'attributes': {'title': 'Kinetic modelling of quantitative proteome data predicts metabolic reprogramming of liver cancer'}, 'links': {'self': '/publications/200'}}
# https://seek.lisym.org/publications/200.json
# {'id': '201', 'type': 'publications', 'attributes': {'title': 'Metabolic modelling of kidney diseases: Lessons learned from the liver'}, 'links': {'self': '/publications/201'}}
# https://seek.lisym.org/publications/201.json
# {'id': '202', 'type': 'publications', 'attributes': {'title': 'Quantitative MRI for Assessment of Treatment Outcomes in a Rabbit VX2 Hepatic Tumor Model'}, 'links': {'self': '/publications/202'}}
# https://seek.lisym.org/publications/202.json
# {'id': '203', 'type': 'publications', 'attributes': {'title': 'Diagnostic performance of tomoelastography of the liver and spleen for staging hepatic fibrosis'}, 'links': {'self': '/publications/203'}}
# https://seek.lisym.org/publications/203.json
# {'id': '205', 'type': 'publications', 'attributes': {'title': 'ECM1 stabilizes matrix deposited latent TGF-β to maintain liver homeostasis and prevent fibrogenesis'}, 'links': {'self': '/publications/205'}}
# https://seek.lisym.org/publications/205.json
# {'id': '206', 'type': 'publications', 'attributes': {'title': 'Editorial: Systems Biology and Bioinformatics in Gastroenterology and Hepatology'}, 'links': {'self': '/publications/206'}}
# https://seek.lisym.org/publications/206.json
# {'id': '207', 'type': 'publications', 'attributes': {'title': 'TGF-beta in Hepatic Stellate Cell Activation and Liver Fibrogenesis-Updated 2019.'}, 'links': {'self': '/publications/207'}}
# https://seek.lisym.org/publications/207.json
# {'id': '208', 'type': 'publications', 'attributes': {'title': 'Adenovirusmediated overexpression of bone morphogenetic protein9 promotes methionine choline deficiencyinduced nonalcoholic steatohepatitis in nonobese mice.'}, 'links': {'self': '/publications/208'}}
# https://seek.lisym.org/publications/208.json
# {'id': '209', 'type': 'publications', 'attributes': {'title': 'Assessment of Chemotherapy-Induced Organ Damage with Ga-68 Labeled Duramycin.'}, 'links': {'self': '/publications/209'}}
# https://seek.lisym.org/publications/209.json
# {'id': '210', 'type': 'publications', 'attributes': {'title': 'Mutual Zonated Interactions of Wnt and Hh Signaling Are Orchestrating the Metabolism of the Adult Liver in Mice and Human'}, 'links': {'self': '/publications/210'}}
# https://seek.lisym.org/publications/210.json
# {'id': '211', 'type': 'publications', 'attributes': {'title': 'TGF-β2 silencing to target biliary-derived liver diseases'}, 'links': {'self': '/publications/211'}}
# https://seek.lisym.org/publications/211.json
# {'id': '212', 'type': 'publications', 'attributes': {'title': 'Transfer of regulatory knowledge from human to mouse for functional genomics analysis'}, 'links': {'self': '/publications/212'}}
# https://seek.lisym.org/publications/212.json
# {'id': '213', 'type': 'publications', 'attributes': {'title': 'Intravital multi-modal flux analysis reveals the transport mechanism of bile acids through hepatic microconduits'}, 'links': {'self': '/publications/213'}}
# https://seek.lisym.org/publications/213.json
# {'id': '214', 'type': 'publications', 'attributes': {'title': 'Robustness and applicability of transcription factor and pathway analysis tools on single-cell RNA-seq data'}, 'links': {'self': '/publications/214'}}
# https://seek.lisym.org/publications/214.json
# {'id': '215', 'type': 'publications', 'attributes': {'title': 'Bile canaliculi remodeling activates\n              YAP\n              via the actin cytoskeleton during liver regeneration'}, 'links': {'self': '/publications/215'}}
# https://seek.lisym.org/publications/215.json
# {'id': '216', 'type': 'publications', 'attributes': {'title': 'Liver Fibrosis and Metabolic Alterations in Adults With alpha-1-antitrypsin Deficiency Caused by the Pi*ZZ Mutation.'}, 'links': {'self': '/publications/216'}}
# https://seek.lisym.org/publications/216.json
# {'id': '217', 'type': 'publications', 'attributes': {'title': 'Transient elastography for screening of liver fibrosis: Cost-effectiveness analysis from six prospective cohorts in Europe and Asia.'}, 'links': {'self': '/publications/217'}}
# https://seek.lisym.org/publications/217.json
# --------------------------------------------------------------------
# NameError                          Traceback (most recent call last)
# <ipython-input-15-f278006cb512> in <module>
#      43
#      44     publications.append(parsePublication(fullPublicationData))
# ---> 45 print(len(allPublicationData))
#      46 # now "publications" contains a list of hashes with publication information
#
# NameError: name 'allPublicationData' is not defined

# %%
print(publications[0])
# Out:
# {'id': '1', 'pmid': 28187405, 'doi': None, 'link': 'https://www.ncbi.nlm.nih.gov/pubmed/28187405', 'title': 'Specifications of Standards in Systems and Synthetic Biology: Status and Developments in 2016', 'authors': ['F. Schreiber', 'G. D. Bader', 'P. Gleeson', 'Martin Golebiewski', 'M. Hucka', 'N. Le Novere', 'C. Myers', 'D. Nickerson', 'B. Sommer', 'D. Walthemath'], 'abstract': 'Standards are essential to the advancement of science and technology. In systems and synthetic biology, numerous standards and associated tools have been developed over the last 16 years. This special issue of the Journal of Integrative Bioinformatics aims to support the exchange, distribution and archiving of these standards, as well as to provide centralised and easily citable access to them.', 'citation': 'J Integr Bioinform. 2016 Dec 18;13(3):289. doi: 10.2390/biecoll-jib-2016-289.', 'journal': 'J Integr Bioinform', 'published_date': '2017-02-12', 'projects': {'data': [{'id': '2', 'type': 'projects'}]}}

# %%
import pandas as pd
df_pub = pd.DataFrame(publications)
# df_pub = df_pub[["title", "journal", "published_date", "citation", "authors", "projects"]]

# save as excel file
writer = pd.ExcelWriter('./results/publications.xlsx', engine='xlsxwriter')
df_pub.to_excel(writer, sheet_name='Publications', index=False)
writer.save()

df_pub.head(10)
# Out:
#    id        pmid                         doi  \
# 0   1  28187405.0                        None
# 1   2  27899646.0                        None
# 2   3  27051515.0                        None
# 3   4         NaN   10.1007/s13222-016-0243-4
# 4   5  27587694.0                        None
# 5   6  27494133.0                        None
# 6   7  27588423.0                        None
# 7  11         NaN  10.1016/j.jhep.2015.11.018
# 8  12         NaN   10.1007/s00204-016-1906-5
# 9  13         NaN           10.1002/hep.28965
#
#                                            link  \
# 0  https://www.ncbi.nlm.nih.gov/pubmed/28187405
# 1  https://www.ncbi.nlm.nih.gov/pubmed/27899646
# 2  https://www.ncbi.nlm.nih.gov/pubmed/27051515
# 3          https://www.ncbi.nlm.nih.gov/pubmed/
# 4  https://www.ncbi.nlm.nih.gov/pubmed/27587694
# 5  https://www.ncbi.nlm.nih.gov/pubmed/27494133
# 6  https://www.ncbi.nlm.nih.gov/pubmed/27588423
# 7          https://www.ncbi.nlm.nih.gov/pubmed/
# 8          https://www.ncbi.nlm.nih.gov/pubmed/
# 9          https://www.ncbi.nlm.nih.gov/pubmed/
#
#                                                title  \
# 0  Specifications of Standards in Systems and Syn...
# 1  FAIRDOMHub: a repository and collaboration env...
# 2  The Human Physiome: how standards, software an...
# 3  SABIO-RK, von Daten in der Publikation zur Suc...
# 4  L1 regularization facilitates detection of cel...
# 5  Identification of Cell Type-Specific Differenc...
# 6  Driving the Model to Its Limit: Profile Likeli...
# 7  Model-guided identification of a therapeutic s...
# 8  In vivo imaging of systemic transport and elim...
# 9  The ascending pathophysiology of cholestatic l...
#
#                                              authors  \
# 0  [F. Schreiber, G. D. Bader, P. Gleeson, Martin...
# 1  [K. Wolstencroft, Olga Krebs, J. L. Snoep, N. ...
# 2  [D. Nickerson, K. Atalag, B. de Bono, J. Geige...
# 3  [Wolfgang Müller, Meik Bittkowski, Martin Gole...
# 4               [B. Steiert, Jens Timmer, C. Kreutz]
# 5  [R. Merkle, B. Steiert, F. Salopiata, S. Depne...
# 6  [T. Maiwald, H. Hass, B. Steiert, J. Vanlier, ...
# 7  [Ahmed Ghallab, Géraldine Cellière, Sebastian ...
# 8  [Raymond Reif, Ahmed Ghallab, Lynette Beattie,...
# 9  [Peter Jansen, Ahmed Ghallab, Nachiket Vartak,...
#
#                                             abstract  \
# 0  Standards are essential to the advancement of ...
# 1  The FAIRDOMHub is a repository for publishing ...
# 2  Reconstructing and understanding the Human Phy...
# 3                                               None
# 4  MOTIVATION: A major goal of drug development i...
# 5  Lung cancer, with its most prevalent form non-...
# 6  In systems biology, one of the major tasks is ...
# 7  BACKGROUND & AIMS: \r\n\r\nRecently, spatial-t...
# 8  \r\n\r\nWe describe a two-photon microscopy-ba...
# 9  In this review we develop the argument that ch...
#
#                                             citation                journal  \
# 0  J Integr Bioinform. 2016 Dec 18;13(3):289. doi...     J Integr Bioinform
# 1  Nucleic Acids Res. 2017 Jan 4;45(D1):D404-D407...      Nucleic Acids Res
# 2  Interface Focus. 2016 Apr 6;6(2):20150103. doi...        Interface Focus
# 3                      Datenbank Spektrum 17(1) : 21     Datenbank Spektrum
# 4  Bioinformatics. 2016 Sep 1;32(17):i718-i726. d...         Bioinformatics
# 5  PLoS Comput Biol. 2016 Aug 5;12(8):e1005049. d...       PLoS Comput Biol
# 6  PLoS One. 2016 Sep 2;11(9):e0162366. doi: 10.1...               PLoS One
# 7                  Journal of Hepatology 64(4) : 860  Journal of Hepatology
# 8                          Arch Toxicol 91(3) : 1335           Arch Toxicol
# 9                             Hepatology 65(2) : 722             Hepatology
#
#   published_date                                     projects
# 0     2017-02-12  {'data': [{'id': '2', 'type': 'projects'}]}
# 1     2016-12-03  {'data': [{'id': '2', 'type': 'projects'}]}
# 2     2016-04-07  {'data': [{'id': '2', 'type': 'projects'}]}
# 3     2017-03-01  {'data': [{'id': '2', 'type': 'projects'}]}
# 4     2016-09-03  {'data': [{'id': '5', 'type': 'projects'}]}
# 5     2016-08-06  {'data': [{'id': '5', 'type': 'projects'}]}
# 6     2016-09-03  {'data': [{'id': '5', 'type': 'projects'}]}
# 7     2016-04-01  {'data': [{'id': '7', 'type': 'projects'}]}
# 8     2017-03-01  {'data': [{'id': '7', 'type': 'projects'}]}
# 9     2017-02-01  {'data': [{'id': '7', 'type': 'projects'}]}

# %% [markdown]
# ## Create a publication "report"

# %%
import json
project_cache = dict()

def get_project(pid):
    """ Get project information, with caching. """
    if not pid in project_cache:
        url = SEEK_URL + 'projects/{}.json'.format(pid)
        project_cache[pid] = get_json(url)

    return project_cache[pid]

def createProjectReport(projectData):
    for project in projectData['data']:
        pid =  project['id']
        pdata = get_project(pid)
        title = pdata['attributes']['title'];
        print(json.dumps(pdata, indent=4, sort_keys=True))
    
def create_report(pub_json):
    print()
    print('------------------------------------------------------------------------------')
    for key in ['title', 'authors', 'citation', 'published_data', 'journal']:
        print(pub_json.get(key))
    
    # project information for publication
    projects = pub_json['projects']
    createProjectReport(projects)

# %%
# now iterate over all publications
# and create a small report for each of them
for p in publications[0:3]:
    create_report(p)
# Out:
# ------------------------------------------------------------------------------
# Specifications of Standards in Systems and Synthetic Biology: Status and Developments in 2016
# ['F. Schreiber', 'G. D. Bader', 'P. Gleeson', 'Martin Golebiewski', 'M. Hucka', 'N. Le Novere', 'C. Myers', 'D. Nickerson', 'B. Sommer', 'D. Walthemath']
# J Integr Bioinform. 2016 Dec 18;13(3):289. doi: 10.2390/biecoll-jib-2016-289.
# None
# J Integr Bioinform
# https://seek.lisym.org/projects/2.json
# {
#     "attributes": {
#         "avatar": null,
#         "default_license": "notspecified",
#         "default_policy": {
#             "access": "no_access",
#             "permissions": [
#                 {
#                     "access": "download",
#                     "resource": {
#                         "id": "2",
#                         "type": "projects"
#                     }
#                 },
#                 {
#                     "access": "view",
#                     "resource": {
#                         "id": "13",
#                         "type": "projects"
#                     }
#                 }
#             ]
#         },
#         "description": "Major infrastructure backbone of the whole LiSyM network. It comprises the core management tasks of the program directorate and the scientific project management, as well as the central data management. The data management concept relies on FAIRDOM (http://fair-dom.org) and uses the LiSyM SEEK platform as a major hub for exchanging data, models, SOPs and other information, as well as yellow pages for the projects with its corresponding members, institutions, events, presentations and publications.",
#         "title": "LiSyM Core Infrastructure and Management (LiSyM-PD)",
#         "web_page": null,
#         "wiki_page": null
#     },
#     "id": "2",
#     "links": {
#         "self": "/projects/2"
#     },
#     "meta": {
#         "api_version": "0.2",
#         "base_url": "https://seek.lisym.org",
#         "created": "2017-02-20T14:27:57.000Z",
#         "modified": "2020-03-06T16:28:23.000Z",
#         "uuid": "b251ac00-d9a6-0134-44c3-0242ac110002"
#     },
#     "relationships": {
#         "assays": {
#             "data": []
#         },
#         "data_files": {
#             "data": [
#                 {
#                     "id": "4",
#                     "type": "data_files"
#                 },
#                 {
#                     "id": "13",
#                     "type": "data_files"
#                 }
#             ]
#         },
#         "documents": {
#             "data": [
#                 {
#                     "id": "113",
#                     "type": "documents"
#                 },
#                 {
#                     "id": "120",
#                     "type": "documents"
#                 },
#                 {
#                     "id": "121",
#                     "type": "documents"
#                 },
#                 {
#                     "id": "122",
#                     "type": "documents"
#                 }
#             ]
#         },
#         "events": {
#             "data": [
#                 {
#                     "id": "1",
#                     "type": "events"
#                 },
#                 {
#                     "id": "2",
#                     "type": "events"
#                 },
#                 {
#                     "id": "4",
#                     "type": "events"
#                 },
#                 {
#                     "id": "5",
#                     "type": "events"
#                 },
#                 {
#                     "id": "6",
#                     "type": "events"
#                 },
#                 {
#                     "id": "7",
#                     "type": "events"
#                 },
#                 {
#                     "id": "10",
#                     "type": "events"
#                 },
#                 {
#                     "id": "25",
#                     "type": "events"
#                 },
#                 {
#                     "id": "33",
#                     "type": "events"
#                 },
#                 {
#                     "id": "34",
#                     "type": "events"
#                 },
#                 {
#                     "id": "38",
#                     "type": "events"
#                 },
#                 {
#                     "id": "43",
#                     "type": "events"
#                 },
#                 {
#                     "id": "51",
#                     "type": "events"
#                 },
#                 {
#                     "id": "57",
#                     "type": "events"
#                 },
#                 {
#                     "id": "58",
#                     "type": "events"
#                 },
#                 {
#                     "id": "60",
#                     "type": "events"
#                 }
#             ]
#         },
#         "institutions": {
#             "data": [
#                 {
#                     "id": "24",
#                     "type": "institutions"
#                 },
#                 {
#                     "id": "37",
#                     "type": "institutions"
#                 },
#                 {
#                     "id": "61",
#                     "type": "institutions"
#                 }
#             ]
#         },
#         "investigations": {
#             "data": []
#         },
#         "models": {
#             "data": []
#         },
#         "organisms": {
#             "data": []
#         },
#         "people": {
#             "data": [
#                 {
#                     "id": "3",
#                     "type": "people"
#                 },
#                 {
#                     "id": "4",
#                     "type": "people"
#                 },
#                 {
#                     "id": "31",
#                     "type": "people"
#                 },
#                 {
#                     "id": "61",
#                     "type": "people"
#                 },
#                 {
#                     "id": "74",
#                     "type": "people"
#                 },
#                 {
#                     "id": "97",
#                     "type": "people"
#                 },
#                 {
#                     "id": "111",
#                     "type": "people"
#                 },
#                 {
#                     "id": "128",
#                     "type": "people"
#                 }
#             ]
#         },
#         "presentations": {
#             "data": [
#                 {
#                     "id": "3",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "25",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "116",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "117",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "118",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "119",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "120",
#                     "type": "presentations"
#                 }
#             ]
#         },
#         "programmes": {
#             "data": []
#         },
#         "publications": {
#             "data": [
#                 {
#                     "id": "1",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "2",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "3",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "4",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "57",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "105",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "128",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "129",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "130",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "196",
#                     "type": "publications"
#                 }
#             ]
#         },
#         "sops": {
#             "data": []
#         },
#         "studies": {
#             "data": []
#         }
#     },
#     "type": "projects"
# }
#
# ------------------------------------------------------------------------------
# FAIRDOMHub: a repository and collaboration environment for sharing systems biology research
# ['K. Wolstencroft', 'Olga Krebs', 'J. L. Snoep', 'N. J. Stanford', 'F. Bacall', 'Martin Golebiewski', 'R. Kuzyakiv', 'Q. Nguyen', 'S. Owen', 'S. Soiland-Reyes', 'J. Straszewski', 'D. D. van Niekerk', 'A. R. Williams', 'L. Malmstrom', 'B. Rinn', 'Wolfgang Müller', 'C. Goble']
# Nucleic Acids Res. 2017 Jan 4;45(D1):D404-D407. doi: 10.1093/nar/gkw1032. Epub 2016 Nov 28.
# None
# Nucleic Acids Res
# {
#     "attributes": {
#         "avatar": null,
#         "default_license": "notspecified",
#         "default_policy": {
#             "access": "no_access",
#             "permissions": [
#                 {
#                     "access": "download",
#                     "resource": {
#                         "id": "2",
#                         "type": "projects"
#                     }
#                 },
#                 {
#                     "access": "view",
#                     "resource": {
#                         "id": "13",
#                         "type": "projects"
#                     }
#                 }
#             ]
#         },
#         "description": "Major infrastructure backbone of the whole LiSyM network. It comprises the core management tasks of the program directorate and the scientific project management, as well as the central data management. The data management concept relies on FAIRDOM (http://fair-dom.org) and uses the LiSyM SEEK platform as a major hub for exchanging data, models, SOPs and other information, as well as yellow pages for the projects with its corresponding members, institutions, events, presentations and publications.",
#         "title": "LiSyM Core Infrastructure and Management (LiSyM-PD)",
#         "web_page": null,
#         "wiki_page": null
#     },
#     "id": "2",
#     "links": {
#         "self": "/projects/2"
#     },
#     "meta": {
#         "api_version": "0.2",
#         "base_url": "https://seek.lisym.org",
#         "created": "2017-02-20T14:27:57.000Z",
#         "modified": "2020-03-06T16:28:23.000Z",
#         "uuid": "b251ac00-d9a6-0134-44c3-0242ac110002"
#     },
#     "relationships": {
#         "assays": {
#             "data": []
#         },
#         "data_files": {
#             "data": [
#                 {
#                     "id": "4",
#                     "type": "data_files"
#                 },
#                 {
#                     "id": "13",
#                     "type": "data_files"
#                 }
#             ]
#         },
#         "documents": {
#             "data": [
#                 {
#                     "id": "113",
#                     "type": "documents"
#                 },
#                 {
#                     "id": "120",
#                     "type": "documents"
#                 },
#                 {
#                     "id": "121",
#                     "type": "documents"
#                 },
#                 {
#                     "id": "122",
#                     "type": "documents"
#                 }
#             ]
#         },
#         "events": {
#             "data": [
#                 {
#                     "id": "1",
#                     "type": "events"
#                 },
#                 {
#                     "id": "2",
#                     "type": "events"
#                 },
#                 {
#                     "id": "4",
#                     "type": "events"
#                 },
#                 {
#                     "id": "5",
#                     "type": "events"
#                 },
#                 {
#                     "id": "6",
#                     "type": "events"
#                 },
#                 {
#                     "id": "7",
#                     "type": "events"
#                 },
#                 {
#                     "id": "10",
#                     "type": "events"
#                 },
#                 {
#                     "id": "25",
#                     "type": "events"
#                 },
#                 {
#                     "id": "33",
#                     "type": "events"
#                 },
#                 {
#                     "id": "34",
#                     "type": "events"
#                 },
#                 {
#                     "id": "38",
#                     "type": "events"
#                 },
#                 {
#                     "id": "43",
#                     "type": "events"
#                 },
#                 {
#                     "id": "51",
#                     "type": "events"
#                 },
#                 {
#                     "id": "57",
#                     "type": "events"
#                 },
#                 {
#                     "id": "58",
#                     "type": "events"
#                 },
#                 {
#                     "id": "60",
#                     "type": "events"
#                 }
#             ]
#         },
#         "institutions": {
#             "data": [
#                 {
#                     "id": "24",
#                     "type": "institutions"
#                 },
#                 {
#                     "id": "37",
#                     "type": "institutions"
#                 },
#                 {
#                     "id": "61",
#                     "type": "institutions"
#                 }
#             ]
#         },
#         "investigations": {
#             "data": []
#         },
#         "models": {
#             "data": []
#         },
#         "organisms": {
#             "data": []
#         },
#         "people": {
#             "data": [
#                 {
#                     "id": "3",
#                     "type": "people"
#                 },
#                 {
#                     "id": "4",
#                     "type": "people"
#                 },
#                 {
#                     "id": "31",
#                     "type": "people"
#                 },
#                 {
#                     "id": "61",
#                     "type": "people"
#                 },
#                 {
#                     "id": "74",
#                     "type": "people"
#                 },
#                 {
#                     "id": "97",
#                     "type": "people"
#                 },
#                 {
#                     "id": "111",
#                     "type": "people"
#                 },
#                 {
#                     "id": "128",
#                     "type": "people"
#                 }
#             ]
#         },
#         "presentations": {
#             "data": [
#                 {
#                     "id": "3",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "25",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "116",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "117",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "118",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "119",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "120",
#                     "type": "presentations"
#                 }
#             ]
#         },
#         "programmes": {
#             "data": []
#         },
#         "publications": {
#             "data": [
#                 {
#                     "id": "1",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "2",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "3",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "4",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "57",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "105",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "128",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "129",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "130",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "196",
#                     "type": "publications"
#                 }
#             ]
#         },
#         "sops": {
#             "data": []
#         },
#         "studies": {
#             "data": []
#         }
#     },
#     "type": "projects"
# }
#
# ------------------------------------------------------------------------------
# The Human Physiome: how standards, software and innovative service infrastructures are providing the building blocks to make it achievable
# ['D. Nickerson', 'K. Atalag', 'B. de Bono', 'J. Geiger', 'C. Goble', 'S. Hollmann', 'J. Lonien', 'Wolfgang Müller', 'B. Regierer', 'N. J. Stanford', 'Martin Golebiewski', 'P. Hunter']
# Interface Focus. 2016 Apr 6;6(2):20150103. doi: 10.1098/rsfs.2015.0103.
# None
# Interface Focus
# {
#     "attributes": {
#         "avatar": null,
#         "default_license": "notspecified",
#         "default_policy": {
#             "access": "no_access",
#             "permissions": [
#                 {
#                     "access": "download",
#                     "resource": {
#                         "id": "2",
#                         "type": "projects"
#                     }
#                 },
#                 {
#                     "access": "view",
#                     "resource": {
#                         "id": "13",
#                         "type": "projects"
#                     }
#                 }
#             ]
#         },
#         "description": "Major infrastructure backbone of the whole LiSyM network. It comprises the core management tasks of the program directorate and the scientific project management, as well as the central data management. The data management concept relies on FAIRDOM (http://fair-dom.org) and uses the LiSyM SEEK platform as a major hub for exchanging data, models, SOPs and other information, as well as yellow pages for the projects with its corresponding members, institutions, events, presentations and publications.",
#         "title": "LiSyM Core Infrastructure and Management (LiSyM-PD)",
#         "web_page": null,
#         "wiki_page": null
#     },
#     "id": "2",
#     "links": {
#         "self": "/projects/2"
#     },
#     "meta": {
#         "api_version": "0.2",
#         "base_url": "https://seek.lisym.org",
#         "created": "2017-02-20T14:27:57.000Z",
#         "modified": "2020-03-06T16:28:23.000Z",
#         "uuid": "b251ac00-d9a6-0134-44c3-0242ac110002"
#     },
#     "relationships": {
#         "assays": {
#             "data": []
#         },
#         "data_files": {
#             "data": [
#                 {
#                     "id": "4",
#                     "type": "data_files"
#                 },
#                 {
#                     "id": "13",
#                     "type": "data_files"
#                 }
#             ]
#         },
#         "documents": {
#             "data": [
#                 {
#                     "id": "113",
#                     "type": "documents"
#                 },
#                 {
#                     "id": "120",
#                     "type": "documents"
#                 },
#                 {
#                     "id": "121",
#                     "type": "documents"
#                 },
#                 {
#                     "id": "122",
#                     "type": "documents"
#                 }
#             ]
#         },
#         "events": {
#             "data": [
#                 {
#                     "id": "1",
#                     "type": "events"
#                 },
#                 {
#                     "id": "2",
#                     "type": "events"
#                 },
#                 {
#                     "id": "4",
#                     "type": "events"
#                 },
#                 {
#                     "id": "5",
#                     "type": "events"
#                 },
#                 {
#                     "id": "6",
#                     "type": "events"
#                 },
#                 {
#                     "id": "7",
#                     "type": "events"
#                 },
#                 {
#                     "id": "10",
#                     "type": "events"
#                 },
#                 {
#                     "id": "25",
#                     "type": "events"
#                 },
#                 {
#                     "id": "33",
#                     "type": "events"
#                 },
#                 {
#                     "id": "34",
#                     "type": "events"
#                 },
#                 {
#                     "id": "38",
#                     "type": "events"
#                 },
#                 {
#                     "id": "43",
#                     "type": "events"
#                 },
#                 {
#                     "id": "51",
#                     "type": "events"
#                 },
#                 {
#                     "id": "57",
#                     "type": "events"
#                 },
#                 {
#                     "id": "58",
#                     "type": "events"
#                 },
#                 {
#                     "id": "60",
#                     "type": "events"
#                 }
#             ]
#         },
#         "institutions": {
#             "data": [
#                 {
#                     "id": "24",
#                     "type": "institutions"
#                 },
#                 {
#                     "id": "37",
#                     "type": "institutions"
#                 },
#                 {
#                     "id": "61",
#                     "type": "institutions"
#                 }
#             ]
#         },
#         "investigations": {
#             "data": []
#         },
#         "models": {
#             "data": []
#         },
#         "organisms": {
#             "data": []
#         },
#         "people": {
#             "data": [
#                 {
#                     "id": "3",
#                     "type": "people"
#                 },
#                 {
#                     "id": "4",
#                     "type": "people"
#                 },
#                 {
#                     "id": "31",
#                     "type": "people"
#                 },
#                 {
#                     "id": "61",
#                     "type": "people"
#                 },
#                 {
#                     "id": "74",
#                     "type": "people"
#                 },
#                 {
#                     "id": "97",
#                     "type": "people"
#                 },
#                 {
#                     "id": "111",
#                     "type": "people"
#                 },
#                 {
#                     "id": "128",
#                     "type": "people"
#                 }
#             ]
#         },
#         "presentations": {
#             "data": [
#                 {
#                     "id": "3",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "25",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "116",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "117",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "118",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "119",
#                     "type": "presentations"
#                 },
#                 {
#                     "id": "120",
#                     "type": "presentations"
#                 }
#             ]
#         },
#         "programmes": {
#             "data": []
#         },
#         "publications": {
#             "data": [
#                 {
#                     "id": "1",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "2",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "3",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "4",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "57",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "105",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "128",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "129",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "130",
#                     "type": "publications"
#                 },
#                 {
#                     "id": "196",
#                     "type": "publications"
#                 }
#             ]
#         },
#         "sops": {
#             "data": []
#         },
#         "studies": {
#             "data": []
#         }
#     },
#     "type": "projects"
# }
